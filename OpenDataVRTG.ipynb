# %%
import pandas as pd
print(pd.__version__)
# Out:
# 0.19.2

# %%
#df = pd.read_json("https://opendata.rdw.nl/resource/w22j-fpxa.json")
#df = pd.read_json("https://opendata.rdw.nl/resource/w22j-fpxa.json?$limit=3000&$$app_token=f4IdwDuoGabq9HF2iHewEiLQC")
df = pd.read_json("https://opendata.rdw.nl/resource/w22j-fpxa.json?$limit=40000")
df.head(5)
# Out:
#                            api_bedrijf_erkenningen  \
# 0  https://opendata.rdw.nl/resource/nmwb-dqkz.json
# 1  https://opendata.rdw.nl/resource/nmwb-dqkz.json
# 2  https://opendata.rdw.nl/resource/nmwb-dqkz.json
# 3  https://opendata.rdw.nl/resource/nmwb-dqkz.json
# 4  https://opendata.rdw.nl/resource/nmwb-dqkz.json
#
#                                        gevelnaam  huisnummer  \
# 0                                            NaN          43
# 1                                        HODE BV          56
# 2  KOOIKER BEDRIJFSWAGENSPUITERIJ.CARROSSERIE BV           4
# 3                            Mister Chi Scooters         423
# 4                                    G.A. AUTO'S         166
#
#   huisnummer_toevoeging                                   naam_bedrijf  \
# 0                   NaN                                     PIEST B.V.
# 1                   NaN                                      HODE B.V.
# ...

# %%
https://data.seattle.gov/resource/3k2p-39jp.json?$$app_token=f4IdwDuoGabq9HF2iHewEiLQC

# %%
len(df)
# Out:
# 26527

# %%
df.to_csv("bedrijven.csv")

# %%
df_vrtg = pd.read_json("https://opendata.rdw.nl/resource/m9d7-ebf2.json?$limit=1000&$$app_token=f4IdwDuoGabq9HF2iHewEiLQC")

# %%
df_vrtg.head(5)
# Out:
#    aanhangwagen_autonoom_geremd  aanhangwagen_middenas_geremd  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    aantal_cilinders  aantal_deuren  aantal_staanplaatsen  aantal_wielen  \
# 0               1.0            NaN                   NaN            NaN
# 1               4.0            4.0                   NaN            4.0
# 2               4.0            2.0                   NaN            4.0
# 3               2.0            0.0                   NaN            2.0
# 4               4.0            2.0                   NaN            4.0
#
#    aantal_zitplaatsen  afstand_hart_koppeling_tot_achterzijde_voertuig  \
# 0                 2.0                                              NaN
# ...
